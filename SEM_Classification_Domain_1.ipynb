# %%
import pandas as pd
import numpy as np
from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',None)

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/My Drive/Group/Feature Space.csv")
df.head()
# Out:
#    Haralick_Mean_Value  Fractal_Dimension     FFT_Mean      FFT_Std  SSM_Mean  \
# 0           403.427286           2.545389  2430.043865  51019.00172  0.019887
# 1           171.471253           2.568873  2064.858462  22716.42011  0.016167
# 2           339.014122           2.798025  2784.139115  40702.89564  0.039668
# 3           432.886532           2.826948  3208.682357  38195.00751  0.017798
# 4           481.977900           2.997419  6333.498952  36836.65011  0.016078
#
#    SSM_Median  SSM_Std_Dev  Mean_Entropy  Range_Entropy  Median_Entropy  \
# 0    0.010297     0.250425      3.211451       1.949438        3.028394
# 1    0.000639     0.145739      2.723481       1.837931        2.588493
# 2   -0.002656     0.221830      3.824544       2.445337        3.990818
# 3   -0.002418     0.305185      3.614254       1.786809        3.613561
# 4    0.005391     0.197852      4.181687       1.037032        4.084344
#
#              Aspect_Ratio              Label
# 0  Variable aspect ratio   Patterned_surface
# 1  Variable aspect ratio   Patterned_surface
# 2  Variable aspect ratio   Patterned_surface
# 3  Variable aspect ratio   Patterned_surface
# 4  Variable aspect ratio   Patterned_surface

# %%
df.shape
# Out:
# (6120, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Haralick_Mean_Value  6120 non-null   float64
#  1   Fractal_Dimension    6120 non-null   float64
#  2   FFT_Mean             6120 non-null   float64
#  3   FFT_Std              6120 non-null   float64
#  4   SSM_Mean             6120 non-null   float64
#  5   SSM_Median           6120 non-null   float64
#  6   SSM_Std_Dev          6120 non-null   float64
#  7   Mean_Entropy         6120 non-null   float64
#  8   Range_Entropy        6120 non-null   float64
#  9   Median_Entropy       6120 non-null   float64
#  10  Aspect_Ratio         6120 non-null   object
#  11  Label                6120 non-null   object
# dtypes: float64(10), object(2)
# memory usage: 573.9+ KB

# %%
df.isnull().sum()
# Out:
# Haralick_Mean_Value    0
# Fractal_Dimension      0
# FFT_Mean               0
# FFT_Std                0
# SSM_Mean               0
# SSM_Median             0
# SSM_Std_Dev            0
# Mean_Entropy           0
# Range_Entropy          0
# Median_Entropy         0
# Aspect_Ratio           0
# Label                  0
# dtype: int64

# %%
df['Label'].value_counts()
# Out:
# Label
# Patterned_surface              612
# Porous_Sponge                  612
# Powder                         612
# Tips                           612
# Particles                      612
# Fibres                         612
# Films_Coated_Surface           612
# Nanowires                      612
# MEMS_devices_and_electrodes    612
# Biological                     612
# Name: count, dtype: int64

# %%
#df.drop((np.where(df['Label'].isin(["Fibres","MEMS_devices_and_electrodes","Particles"]))[0]), inplace = True)

# %%
df['Label'].value_counts()
# Out:
# Label
# Patterned_surface              612
# Porous_Sponge                  612
# Powder                         612
# Tips                           612
# Particles                      612
# Fibres                         612
# Films_Coated_Surface           612
# Nanowires                      612
# MEMS_devices_and_electrodes    612
# Biological                     612
# Name: count, dtype: int64

# %%
X = df.drop(['Label'], axis=1)
y = df['Label']

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for column in X.columns:
    if X[column].dtype == 'object':
        X[column] = le.fit_transform(X[column])

# %%
X.head()
# Out:
#    Haralick_Mean_Value  Fractal_Dimension     FFT_Mean      FFT_Std  SSM_Mean  \
# 0           403.427286           2.545389  2430.043865  51019.00172  0.019887
# 1           171.471253           2.568873  2064.858462  22716.42011  0.016167
# 2           339.014122           2.798025  2784.139115  40702.89564  0.039668
# 3           432.886532           2.826948  3208.682357  38195.00751  0.017798
# 4           481.977900           2.997419  6333.498952  36836.65011  0.016078
#
#    SSM_Median  SSM_Std_Dev  Mean_Entropy  Range_Entropy  Median_Entropy  \
# 0    0.010297     0.250425      3.211451       1.949438        3.028394
# 1    0.000639     0.145739      2.723481       1.837931        2.588493
# 2   -0.002656     0.221830      3.824544       2.445337        3.990818
# 3   -0.002418     0.305185      3.614254       1.786809        3.613561
# 4    0.005391     0.197852      4.181687       1.037032        4.084344
#
#    Aspect_Ratio
# 0             2
# 1             2
# 2             2
# 3             2
# 4             2

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
print("X_train: " + str(X_train.shape))
print("y_train: " + str(y_train.shape))
print("X_test: " + str(X_test.shape))
print("y_test: " + str(y_test.shape))
# Out:
# X_train: (4590, 11)
# y_train: (4590,)
# X_test: (1530, 11)
# y_test: (1530,)

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

lr = LogisticRegression(random_state=42)
lr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
y_pred = lr.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print("Accuracy:", accuracy)


plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=lr.classes_, yticklabels=lr.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Accuracy: 0.23202614379084968

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

rf_classifier = RandomForestClassifier(random_state=42)
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_classifier.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8045751633986928

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=rf_classifier.classes_, yticklabels=rf_classifier.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV


rf_classifier = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Perform Grid Search to find the best hyperparameters
grid_search = GridSearchCV(estimator=rf_classifier, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)

# Train the Random Forest classifier with the best hyperparameters
best_rf_classifier = RandomForestClassifier(random_state=42, **best_params)
best_rf_classifier.fit(X_train, y_train)

# Make predictions
y_pred = best_rf_classifier.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Accuracy: 0.8045751633986928

# %%
# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Print classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)

# Plot confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=best_rf_classifier.classes_, yticklabels=best_rf_classifier.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Classification Report:
#                              precision    recall  f1-score   support
#
#                  Biological       0.69      0.75      0.72       151
#                      Fibres       1.00      1.00      1.00       139
#        Films_Coated_Surface       0.79      0.90      0.84       148
# MEMS_devices_and_electrodes       0.65      0.67      0.66       146
#                   Nanowires       0.96      0.88      0.92       162
#                   Particles       0.81      0.68      0.74       166
#           Patterned_surface       0.67      0.56      0.61       170
#               Porous_Sponge       0.89      0.97      0.93       157
#                      Powder       0.72      0.73      0.72       152
#                        Tips       0.87      0.96      0.91       139
#
#                    accuracy                           0.80      1530
#                   macro avg       0.81      0.81      0.81      1530
#                weighted avg       0.80      0.80      0.80      1530

# %%
misclassified_indices = np.where(y_pred != y_test)[0]
misclassified_features = X_test.iloc[misclassified_indices]
true_labels = y_test.iloc[misclassified_indices]
predicted_labels = y_pred[misclassified_indices]

# Display misclassified instances and true labels
for i in range(len(misclassified_indices)):
    print("Instance:", misclassified_indices[i])
    #print("Features:", misclassified_features.iloc[i])
    print("True Label:", true_labels.iloc[i])
    print("Predicted Label:", predicted_labels[i])
    print("--------------------")
# Out:
# Instance: 7
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 8
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 11
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 12
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 15
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 16
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 23
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 26
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 28
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 37
# True Label: Powder
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 39
# True Label: Particles
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 52
# True Label: Patterned_surface
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 57
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 60
# True Label: Particles
# Predicted Label: Powder
# --------------------
# Instance: 70
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 78
# True Label: Biological
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 86
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 96
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 100
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 104
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 110
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 112
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Powder
# --------------------
# Instance: 114
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 116
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 117
# True Label: Powder
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 128
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 130
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 137
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 138
# True Label: Patterned_surface
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 140
# True Label: Films_Coated_Surface
# Predicted Label: Biological
# --------------------
# Instance: 141
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 147
# True Label: Biological
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 162
# True Label: Patterned_surface
# Predicted Label: Particles
# --------------------
# Instance: 166
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 170
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 176
# True Label: Biological
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 187
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 190
# True Label: Powder
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 198
# True Label: Films_Coated_Surface
# Predicted Label: Powder
# --------------------
# Instance: 199
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 202
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 203
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 208
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 213
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 217
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 219
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 222
# True Label: Porous_Sponge
# Predicted Label: Biological
# --------------------
# Instance: 224
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 225
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 228
# True Label: Powder
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 233
# True Label: Biological
# Predicted Label: Patterned_surface
# --------------------
# Instance: 234
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 236
# True Label: Films_Coated_Surface
# Predicted Label: Biological
# --------------------
# Instance: 239
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 242
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 249
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 252
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 269
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 272
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 276
# True Label: Particles
# Predicted Label: Powder
# --------------------
# Instance: 278
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 283
# True Label: Powder
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 284
# True Label: Films_Coated_Surface
# Predicted Label: Biological
# --------------------
# Instance: 285
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 286
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 293
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 298
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 299
# True Label: Powder
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 308
# True Label: Biological
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 320
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 322
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 334
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 337
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 339
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 340
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 346
# True Label: Films_Coated_Surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 349
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 352
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 359
# True Label: Powder
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 368
# True Label: Patterned_surface
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 376
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 383
# True Label: Patterned_surface
# Predicted Label: Particles
# --------------------
# Instance: 388
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 398
# True Label: Biological
# Predicted Label: Patterned_surface
# --------------------
# Instance: 399
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 405
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 412
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 415
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 419
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 431
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 437
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 439
# True Label: Powder
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 447
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 448
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 450
# True Label: Porous_Sponge
# Predicted Label: Biological
# --------------------
# Instance: 453
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 460
# True Label: Patterned_surface
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 462
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 466
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 470
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 475
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 478
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 480
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 483
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 487
# True Label: Particles
# Predicted Label: Powder
# --------------------
# Instance: 496
# True Label: Particles
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 508
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 509
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 510
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 519
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 521
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 540
# True Label: Particles
# Predicted Label: Powder
# --------------------
# Instance: 542
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 545
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 548
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 552
# True Label: Patterned_surface
# Predicted Label: Particles
# --------------------
# Instance: 554
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 558
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 561
# True Label: Powder
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 570
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 573
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Biological
# --------------------
# Instance: 575
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 576
# True Label: Biological
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 582
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 587
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 589
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 591
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 595
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 596
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 600
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 607
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 610
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 614
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 616
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 617
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 620
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 624
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Powder
# --------------------
# Instance: 630
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 631
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 647
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 650
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 658
# True Label: Tips
# Predicted Label: Nanowires
# --------------------
# Instance: 662
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 664
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 674
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 681
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 682
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 683
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 688
# True Label: Films_Coated_Surface
# Predicted Label: Patterned_surface
# --------------------
# Instance: 694
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 709
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 712
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 718
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 724
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 729
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 740
# True Label: Powder
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 741
# True Label: Patterned_surface
# Predicted Label: Particles
# --------------------
# Instance: 744
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 747
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 762
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 763
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 767
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 770
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 773
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Biological
# --------------------
# Instance: 784
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 785
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 788
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 792
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 794
# True Label: Powder
# Predicted Label: Particles
# --------------------
# Instance: 797
# True Label: Biological
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 799
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 800
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 801
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 806
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 817
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 818
# True Label: Porous_Sponge
# Predicted Label: Biological
# --------------------
# Instance: 822
# True Label: Films_Coated_Surface
# Predicted Label: Powder
# --------------------
# Instance: 829
# True Label: Tips
# Predicted Label: Nanowires
# --------------------
# Instance: 832
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 836
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 837
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 844
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 845
# True Label: Films_Coated_Surface
# Predicted Label: Biological
# --------------------
# Instance: 847
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 849
# True Label: Films_Coated_Surface
# Predicted Label: Biological
# --------------------
# Instance: 852
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 855
# True Label: Biological
# Predicted Label: Patterned_surface
# --------------------
# Instance: 862
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 868
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 869
# True Label: Powder
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 874
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 881
# True Label: Powder
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 889
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 890
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 892
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 893
# True Label: Biological
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 897
# True Label: Biological
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 900
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 903
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 907
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 908
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 912
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 914
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 915
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 922
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 936
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 938
# True Label: Tips
# Predicted Label: Nanowires
# --------------------
# Instance: 940
# True Label: Films_Coated_Surface
# Predicted Label: Biological
# --------------------
# Instance: 944
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 949
# True Label: Powder
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 960
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 972
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 980
# True Label: Tips
# Predicted Label: Nanowires
# --------------------
# Instance: 985
# True Label: Patterned_surface
# Predicted Label: Particles
# --------------------
# Instance: 989
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 996
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 999
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 1006
# True Label: Porous_Sponge
# Predicted Label: Particles
# --------------------
# Instance: 1013
# True Label: Particles
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 1014
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 1018
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 1023
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1034
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1035
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 1046
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1051
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 1052
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1057
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 1070
# True Label: Films_Coated_Surface
# Predicted Label: Powder
# --------------------
# Instance: 1073
# True Label: Patterned_surface
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 1080
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1092
# True Label: Particles
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 1096
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 1109
# True Label: Biological
# Predicted Label: Particles
# --------------------
# Instance: 1131
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 1135
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1139
# True Label: Tips
# Predicted Label: Nanowires
# --------------------
# Instance: 1146
# True Label: Powder
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 1148
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 1151
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1158
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 1159
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1168
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 1170
# True Label: Tips
# Predicted Label: Nanowires
# --------------------
# Instance: 1173
# True Label: Powder
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 1174
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 1199
# True Label: Powder
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 1204
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1208
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1216
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1223
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1228
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1231
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 1242
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 1251
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1252
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Powder
# --------------------
# Instance: 1254
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 1261
# True Label: Films_Coated_Surface
# Predicted Label: Powder
# --------------------
# Instance: 1262
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1264
# True Label: Films_Coated_Surface
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1270
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 1287
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 1291
# True Label: Biological
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 1293
# True Label: Particles
# Predicted Label: Powder
# --------------------
# Instance: 1299
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1301
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1303
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 1305
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 1321
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 1322
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1336
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Biological
# --------------------
# Instance: 1342
# True Label: Films_Coated_Surface
# Predicted Label: Powder
# --------------------
# Instance: 1344
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Biological
# --------------------
# Instance: 1347
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1348
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 1357
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 1361
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1363
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 1383
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 1387
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1393
# True Label: Particles
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 1394
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 1397
# True Label: Patterned_surface
# Predicted Label: Particles
# --------------------
# Instance: 1404
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1418
# True Label: Films_Coated_Surface
# Predicted Label: Particles
# --------------------
# Instance: 1424
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1427
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 1433
# True Label: Biological
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 1437
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1454
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1456
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1458
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 1466
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1480
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1485
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 1497
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1500
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 1504
# True Label: Powder
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 1508
# True Label: Biological
# Predicted Label: Powder
# --------------------

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

# Create a Decision Tree classifier
dt_classifier = DecisionTreeClassifier(random_state=42)

# Train the classifier
dt_classifier.fit(X_train, y_train)

# Make predictions
y_pred = dt_classifier.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7222222222222222

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=dt_classifier.classes_, yticklabels=dt_classifier.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %% [markdown]
# **XGBOOST**

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the label encoder
label_encoder = LabelEncoder()

# Encode the string labels to integer labels
y_train_encoded = label_encoder.fit_transform(y_train)

y_test_encoded = label_encoder.fit_transform(y_test)

# %%
from xgboost import XGBClassifier

xgb_classifier = XGBClassifier(random_state=42)
xgb_classifier.fit(X_train, y_train_encoded)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_pred = xgb_classifier.predict(X_test)
print("Accuracy:", accuracy_score(y_test_encoded, y_pred))
# Out:
# Accuracy: 0.8032679738562092

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=xgb_classifier.classes_, yticklabels=xgb_classifier.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %% [markdown]
# **Cat Boost**

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.3-cp310-cp310-manylinux2014_x86_64.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.3

# %%
import catboost as cb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix

# Create a CatBoost classifier
catboost_classifier = cb.CatBoostClassifier(random_seed=42)

# Train the classifier
catboost_classifier.fit(X_train, y_train, verbose=0)  # Set verbose=0 to suppress output

# Make predictions
y_pred_catboost = catboost_classifier.predict(X_test)

# Calculate accuracy
accuracy_catboost = accuracy_score(y_test, y_pred_catboost)
print("CatBoost Accuracy:", accuracy_catboost)

# Calculate confusion matrix
conf_matrix_catboost = confusion_matrix(y_test, y_pred_catboost)

# Plot confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_catboost, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=catboost_classifier.classes_, yticklabels=catboost_classifier.classes_)
plt.title("CatBoost Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# CatBoost Accuracy: 0.807843137254902

# %%
from sklearn.metrics import classification_report

# Generate classification report
report = classification_report(y_test, y_pred_catboost, target_names=catboost_classifier.classes_)
print("CatBoost Classification Report:")
print(report)
# Out:
# CatBoost Classification Report:
#                              precision    recall  f1-score   support
#
#                  Biological       0.67      0.74      0.71       151
#                      Fibres       1.00      1.00      1.00       139
#        Films_Coated_Surface       0.83      0.89      0.86       148
# MEMS_devices_and_electrodes       0.66      0.66      0.66       146
#                   Nanowires       0.97      0.88      0.92       162
#                   Particles       0.79      0.67      0.73       166
#           Patterned_surface       0.66      0.61      0.64       170
#               Porous_Sponge       0.92      0.97      0.94       157
#                      Powder       0.73      0.75      0.74       152
#                        Tips       0.87      0.96      0.91       139
#
#                    accuracy                           0.81      1530
#                   macro avg       0.81      0.81      0.81      1530
#                weighted avg       0.81      0.81      0.81      1530

# %%
import numpy as np

# Reshape y_pred_catboost if necessary
if y_pred_catboost.ndim > 1:
    y_pred_catboost = np.squeeze(y_pred_catboost)

misclassified_indices_catboost = np.where(y_pred_catboost != y_test)[0]
misclassified_features_catboost = X_test.iloc[misclassified_indices_catboost]
true_labels_catboost = y_test.iloc[misclassified_indices_catboost]
predicted_labels_catboost = y_pred_catboost[misclassified_indices_catboost]

misclassified_count_catboost = len(misclassified_indices_catboost)

# Display misclassified instances and true labels
for i in range(misclassified_count_catboost):
    print("Instance:", misclassified_indices_catboost[i])
    # Uncomment the line below if you want to display features
    #print("Features:", misclassified_features_catboost.iloc[i])
    print("True Label:", true_labels_catboost.iloc[i])
    print("Predicted Label:", predicted_labels_catboost[i])
    print("--------------------")

# Print summary report
print("Total Misclassified Instances:", misclassified_count_catboost)
# Out:
# Instance: 7
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 8
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 11
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 12
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 15
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 16
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 23
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 26
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 28
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 34
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 37
# True Label: Powder
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 39
# True Label: Particles
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 40
# True Label: Powder
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 57
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 60
# True Label: Particles
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 70
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 78
# True Label: Biological
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 86
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 96
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 100
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 104
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 110
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 112
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Powder
# --------------------
# Instance: 114
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 116
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 117
# True Label: Powder
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 128
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 130
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 135
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 137
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 140
# True Label: Films_Coated_Surface
# Predicted Label: Biological
# --------------------
# Instance: 141
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 162
# True Label: Patterned_surface
# Predicted Label: Particles
# --------------------
# Instance: 166
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 170
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 171
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 176
# True Label: Biological
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 187
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 190
# True Label: Powder
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 199
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 208
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 213
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 222
# True Label: Porous_Sponge
# Predicted Label: Biological
# --------------------
# Instance: 224
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 228
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 233
# True Label: Biological
# Predicted Label: Patterned_surface
# --------------------
# Instance: 234
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 236
# True Label: Films_Coated_Surface
# Predicted Label: Biological
# --------------------
# Instance: 239
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 242
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 249
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 252
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 262
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 269
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 272
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 276
# True Label: Particles
# Predicted Label: Powder
# --------------------
# Instance: 278
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 283
# True Label: Powder
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 284
# True Label: Films_Coated_Surface
# Predicted Label: Biological
# --------------------
# Instance: 293
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 308
# True Label: Biological
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 320
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 322
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 334
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 337
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 339
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 346
# True Label: Films_Coated_Surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 349
# True Label: Particles
# Predicted Label: Powder
# --------------------
# Instance: 351
# True Label: Biological
# Predicted Label: Patterned_surface
# --------------------
# Instance: 352
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 359
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 364
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 366
# True Label: Tips
# Predicted Label: Nanowires
# --------------------
# Instance: 368
# True Label: Patterned_surface
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 373
# True Label: Films_Coated_Surface
# Predicted Label: Powder
# --------------------
# Instance: 388
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 393
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 399
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 405
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 412
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 430
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 431
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 434
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 435
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 439
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 447
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 448
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 450
# True Label: Porous_Sponge
# Predicted Label: Biological
# --------------------
# Instance: 451
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 453
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 460
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 462
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 465
# True Label: Patterned_surface
# Predicted Label: Particles
# --------------------
# Instance: 466
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 467
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 470
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 475
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 478
# True Label: Patterned_surface
# Predicted Label: Particles
# --------------------
# Instance: 480
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 487
# True Label: Particles
# Predicted Label: Powder
# --------------------
# Instance: 496
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 508
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 509
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 510
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 519
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 521
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 540
# True Label: Particles
# Predicted Label: Powder
# --------------------
# Instance: 542
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 545
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 546
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 548
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 558
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 561
# True Label: Powder
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 570
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 573
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 576
# True Label: Biological
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 582
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 587
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 589
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 591
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 595
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 596
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 600
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 607
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 610
# True Label: Powder
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 614
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 617
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 620
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 622
# True Label: Films_Coated_Surface
# Predicted Label: Patterned_surface
# --------------------
# Instance: 624
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 630
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 631
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 634
# True Label: Biological
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 642
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 647
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 649
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 659
# True Label: Biological
# Predicted Label: Particles
# --------------------
# Instance: 662
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 669
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 674
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 680
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 681
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 682
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 683
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 688
# True Label: Films_Coated_Surface
# Predicted Label: Patterned_surface
# --------------------
# Instance: 694
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 709
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 712
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 718
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 722
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 724
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 729
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 741
# True Label: Patterned_surface
# Predicted Label: Particles
# --------------------
# Instance: 744
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 747
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 762
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 763
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 767
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 773
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Biological
# --------------------
# Instance: 781
# True Label: Patterned_surface
# Predicted Label: Particles
# --------------------
# Instance: 784
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 788
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 789
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 792
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 794
# True Label: Powder
# Predicted Label: Particles
# --------------------
# Instance: 797
# True Label: Biological
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 799
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 800
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 801
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 806
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 815
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 817
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 818
# True Label: Porous_Sponge
# Predicted Label: Biological
# --------------------
# Instance: 822
# True Label: Films_Coated_Surface
# Predicted Label: Powder
# --------------------
# Instance: 828
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 829
# True Label: Tips
# Predicted Label: Nanowires
# --------------------
# Instance: 836
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 837
# True Label: Particles
# Predicted Label: Powder
# --------------------
# Instance: 844
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 845
# True Label: Films_Coated_Surface
# Predicted Label: Biological
# --------------------
# Instance: 847
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 849
# True Label: Films_Coated_Surface
# Predicted Label: Biological
# --------------------
# Instance: 852
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 853
# True Label: Films_Coated_Surface
# Predicted Label: Powder
# --------------------
# Instance: 855
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 862
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 869
# True Label: Powder
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 881
# True Label: Powder
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 889
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 890
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 892
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 893
# True Label: Biological
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 897
# True Label: Biological
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 900
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 903
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 907
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 908
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 914
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 915
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 918
# True Label: Films_Coated_Surface
# Predicted Label: Particles
# --------------------
# Instance: 919
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 922
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 927
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 944
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 949
# True Label: Powder
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 960
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 980
# True Label: Tips
# Predicted Label: Nanowires
# --------------------
# Instance: 985
# True Label: Patterned_surface
# Predicted Label: Particles
# --------------------
# Instance: 989
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 996
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 999
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 1006
# True Label: Porous_Sponge
# Predicted Label: Particles
# --------------------
# Instance: 1013
# True Label: Particles
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 1014
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 1018
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 1023
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1034
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1035
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1051
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 1052
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1057
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 1070
# True Label: Films_Coated_Surface
# Predicted Label: Powder
# --------------------
# Instance: 1073
# True Label: Patterned_surface
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 1080
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1092
# True Label: Particles
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 1096
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 1109
# True Label: Biological
# Predicted Label: Particles
# --------------------
# Instance: 1128
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 1131
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 1139
# True Label: Tips
# Predicted Label: Nanowires
# --------------------
# Instance: 1140
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1141
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1146
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1148
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 1151
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1158
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 1159
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1170
# True Label: Tips
# Predicted Label: Nanowires
# --------------------
# Instance: 1174
# True Label: Patterned_surface
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 1184
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 1204
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1208
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1210
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1223
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1224
# True Label: Biological
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1228
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1231
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 1242
# True Label: Patterned_surface
# Predicted Label: Particles
# --------------------
# Instance: 1251
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1252
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Powder
# --------------------
# Instance: 1254
# True Label: Patterned_surface
# Predicted Label: Powder
# --------------------
# Instance: 1261
# True Label: Films_Coated_Surface
# Predicted Label: Powder
# --------------------
# Instance: 1262
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1264
# True Label: Films_Coated_Surface
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1270
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 1287
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 1288
# True Label: Porous_Sponge
# Predicted Label: Biological
# --------------------
# Instance: 1291
# True Label: Biological
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 1293
# True Label: Particles
# Predicted Label: Powder
# --------------------
# Instance: 1299
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1301
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1303
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 1305
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 1322
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1336
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Biological
# --------------------
# Instance: 1341
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1342
# True Label: Films_Coated_Surface
# Predicted Label: Powder
# --------------------
# Instance: 1344
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 1347
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1348
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 1361
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1363
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 1375
# True Label: Biological
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 1387
# True Label: Particles
# Predicted Label: Biological
# --------------------
# Instance: 1394
# True Label: MEMS_devices_and_electrodes
# Predicted Label: Particles
# --------------------
# Instance: 1404
# True Label: Particles
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1415
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 1418
# True Label: Films_Coated_Surface
# Predicted Label: Particles
# --------------------
# Instance: 1424
# True Label: Powder
# Predicted Label: Patterned_surface
# --------------------
# Instance: 1427
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 1429
# True Label: Biological
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 1433
# True Label: Biological
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 1437
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1440
# True Label: Patterned_surface
# Predicted Label: Biological
# --------------------
# Instance: 1456
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1458
# True Label: Nanowires
# Predicted Label: Tips
# --------------------
# Instance: 1469
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1480
# True Label: Patterned_surface
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Instance: 1485
# True Label: Particles
# Predicted Label: Films_Coated_Surface
# --------------------
# Instance: 1497
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1500
# True Label: Powder
# Predicted Label: Biological
# --------------------
# Instance: 1504
# True Label: Powder
# Predicted Label: Porous_Sponge
# --------------------
# Instance: 1508
# True Label: Biological
# Predicted Label: Powder
# --------------------
# Instance: 1521
# True Label: Particles
# Predicted Label: MEMS_devices_and_electrodes
# --------------------
# Total Misclassified Instances: 294
